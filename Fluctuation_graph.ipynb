# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import make_regression
from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
X = [x for x in range(10)]
y = [x for x in range(10)]
plt.plot(X,y,color='r')

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=50, random_state=13)
reg.fit(X,y)
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='r')

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=30, random_state=13)
reg.fit(X,y)
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='r')

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=10, random_state=13)
reg.fit(X,y)
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='r')

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=2, random_state=13)
reg.fit(X,y)
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='r')

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=0, random_state=13)
reg.fit(X,y)
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='r')
